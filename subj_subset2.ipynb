# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import preprocessing
import wfdb
import copy as cp
import scipy.signal as signal
import pickle
from sklearn import preprocessing
from tqdm import tqdm
import os
import re
import pandas as pd
import csv

# %%
record_list = [] # Initialize the array that will hold the list of our records

records = 'mit-bih-dataframes/subject_list.csv' # Get our record list like we did in the initial extraction
with open(records) as rfile:# Load our records into the array
    for record in rfile:
        record = record[0:-1] # The -1 removes the newline ("\n") character from the string
        record_list.append(record)

# %%
subject_dataframes = [] # Initialize our dataframe array

for x in tqdm(record_list): # Extract our dataframes from the CSVs we saved previously
    subject_dataframes.append(pd.read_csv('mit-bih-dataframes/'+x+'.csv', index_col=0))
            # 'index_col=0' loads the index that is saved into the csv as the index rather than another column
# Out:
# 100%|██████████| 23/23 [02:37<00:00,  6.83s/it]
# [         Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.275    -0.210   False   False  False   True
# 1          -0.295    -0.200   False   False  False   True
# 2          -0.310    -0.220   False   False  False   True
# 3          -0.315    -0.225   False   False  False   True
# 4          -0.300    -0.215   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.765    -1.810   False    True  False  False
# 9205756    -0.680    -1.560   False    True  False  False
# 9205757    -0.680    -1.345   False    True  False  False
# 9205758    -0.670    -1.230   False    True  False  False
# 9205759    -0.665    -1.165   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.415    -0.395   False   False  False   True
# 1          -0.415    -0.260   False   False  False   True
# 2          -0.430    -0.185   False   False  False   True
# 3          -0.445    -0.135   False   False  False   True
# 4          -0.460    -0.080   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.220    -0.130   False    True  False  False
# 9205756     0.200    -0.160   False    True  False  False
# 9205757     0.175    -0.140   False    True  False  False
# 9205758     0.080    -0.160   False    True  False  False
# 9205759    -0.030    -0.250   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.375    -0.125   False   False  False   True
# 1          -0.380    -0.110   False   False  False   True
# 2          -0.375    -0.105   False   False  False   True
# 3          -0.395    -0.085   False   False  False   True
# 4          -0.400    -0.075   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.255     0.030   False    True  False  False
# 9205756    -0.255     0.025   False    True  False  False
# 9205757    -0.260     0.015   False    True  False  False
# 9205758    -0.250     0.020   False    True  False  False
# 9205759    -0.240     0.020   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.040    -0.235   False   False  False   True
# 1          -0.055    -0.210   False   False  False   True
# 2          -0.060    -0.210   False   False  False   True
# 3          -0.040    -0.205   False   False  False   True
# 4          -0.030    -0.215   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.040    -0.130   False    True  False  False
# 9205756    -0.045    -0.135   False    True  False  False
# 9205757    -0.050    -0.140   False    True  False  False
# 9205758    -0.050    -0.110   False    True  False  False
# 9205759    -0.035    -0.125   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.285    -0.340   False   False  False   True
# 1          -0.300    -0.320   False   False  False   True
# 2          -0.310    -0.325   False   False  False   True
# 3          -0.300    -0.315   False   False  False   True
# 4          -0.300    -0.310   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.020    -0.215   False    True  False  False
# 9205756     0.000    -0.215   False    True  False  False
# 9205757    -0.010    -0.235   False    True  False  False
# 9205758     0.000    -0.245   False    True  False  False
# 9205759    -0.010    -0.245   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0           0.000    -0.055   False   False  False   True
# 1          -0.025    -0.055   False   False  False   True
# 2          -0.020    -0.105   False   False  False   True
# 3          -0.020    -0.125   False   False  False   True
# 4           0.010    -0.135   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.465    -0.280   False    True  False  False
# 9205756     0.470    -0.310   False    True  False  False
# 9205757     0.495    -0.320   False    True  False  False
# 9205758     0.480    -0.335   False    True  False  False
# 9205759     0.500    -0.345   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.015    -0.320   False   False  False   True
# 1          -0.045    -0.350   False   False  False   True
# 2          -0.030    -0.345   False   False  False   True
# 3          -0.025    -0.360   False   False  False   True
# 4          -0.005    -0.365   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.165    -0.170   False   False  False   True
# 9205756     0.165    -0.185   False   False  False   True
# 9205757     0.120    -0.195   False   False  False   True
# 9205758     0.085    -0.210   False   False  False   True
# 9205759     0.055    -0.255   False   False  False   True
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.130    -0.095   False   False  False   True
# 1          -0.130    -0.095   False   False  False   True
# 2          -0.115    -0.115   False   False  False   True
# 3          -0.110    -0.110   False   False  False   True
# 4          -0.090    -0.130   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -1.500    -0.190   False    True  False  False
# 9205756    -1.425    -0.190   False    True  False  False
# 9205757    -1.425    -0.150   False    True  False  False
# 9205758    -1.535    -0.150   False    True  False  False
# 9205759    -1.595    -0.170   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0           0.045    -0.275   False   False  False   True
# 1           0.070    -0.300   False   False  False   True
# 2           0.100    -0.235   False   False  False   True
# 3           0.130    -0.160   False   False  False   True
# 4           0.160    -0.100   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.145    -0.365   False    True  False  False
# 9205756     0.140    -0.410   False    True  False  False
# 9205757     0.105    -0.380   False    True  False  False
# 9205758     0.070    -0.400   False    True  False  False
# 9205759     0.055    -0.425   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.635    -0.185   False   False  False   True
# 1          -0.540    -0.030   False   False  False   True
# 2          -0.395    -0.055   False   False  False   True
# 3          -0.285    -0.010   False   False  False   True
# 4          -0.270     0.040   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.355    -0.015   False    True  False  False
# 9205756    -0.300    -0.010   False    True  False  False
# 9205757    -0.300     0.015   False    True  False  False
# 9205758    -0.270     0.025   False    True  False  False
# 9205759    -0.270     0.020   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.055     0.130   False   False  False   True
# 1          -0.070     0.075   False   False  False   True
# 2          -0.090     0.090   False   False  False   True
# 3          -0.105     0.085   False   False  False   True
# 4          -0.125     0.095   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.680     1.470   False   False   True  False
# 9205756     0.690     1.480   False   False   True  False
# 9205757     0.715     1.480   False   False   True  False
# 9205758     0.680     1.520   False   False   True  False
# 9205759     0.670     1.535   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.075     0.200   False   False  False   True
# 1          -0.070     0.185   False   False  False   True
# 2          -0.090     0.170   False   False  False   True
# 3          -0.100     0.180   False   False  False   True
# 4          -0.105     0.180   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 8324995     0.065     0.380   False    True  False  False
# 8324996     0.075     0.405   False    True  False  False
# 8324997     0.070     0.410   False    True  False  False
# 8324998     0.075     0.420   False    True  False  False
# 8324999     0.085     0.420   False    True  False  False
#
# [8325000 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.260     0.095   False   False  False   True
# 1          -0.275     0.100   False   False  False   True
# 2          -0.250     0.090   False   False  False   True
# 3          -0.235     0.105   False   False  False   True
# 4          -0.250     0.085   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.230     0.145   False   False   True  False
# 9205756    -0.245     0.155   False   False   True  False
# 9205757    -0.230     0.130   False   False   True  False
# 9205758    -0.230     0.120   False   False   True  False
# 9205759    -0.215     0.110   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.085    -0.155   False   False  False   True
# 1          -0.090    -0.155   False   False  False   True
# 2          -0.085    -0.155   False   False  False   True
# 3          -0.100    -0.170   False   False  False   True
# 4          -0.090    -0.160   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.005    -0.145   False   False   True  False
# 9205756    -0.005    -0.135   False   False   True  False
# 9205757    -0.010    -0.140   False   False   True  False
# 9205758    -0.015    -0.150   False   False   True  False
# 9205759    -0.020    -0.140   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.050    -0.140   False   False  False   True
# 1          -0.030    -0.120   False   False  False   True
# 2           0.000    -0.095   False   False  False   True
# 3           0.010    -0.105   False   False  False   True
# 4           0.000    -0.120   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.155    -0.180   False   False   True  False
# 9205756     0.180    -0.160   False   False   True  False
# 9205757     0.190    -0.170   False   False   True  False
# 9205758     0.195    -0.180   False   False   True  False
# 9205759     0.210    -0.175   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.010    -0.160   False   False  False   True
# 1           0.000    -0.160   False   False  False   True
# 2          -0.015    -0.140   False   False  False   True
# 3          -0.005    -0.140   False   False  False   True
# 4           0.000    -0.150   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.115    -0.045   False    True  False  False
# 9205756     0.120    -0.065   False    True  False  False
# 9205757     0.125    -0.055   False    True  False  False
# 9205758     0.130    -0.035   False    True  False  False
# 9205759     0.125    -0.035   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.160     0.025   False   False  False   True
# 1          -0.155     0.015   False   False  False   True
# 2          -0.150     0.015   False   False  False   True
# 3          -0.160     0.030   False   False  False   True
# 4          -0.150     0.050   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.225     0.565   False   False   True  False
# 9205756     0.235     0.555   False   False   True  False
# 9205757     0.230     0.560   False   False   True  False
# 9205758     0.240     0.575   False   False   True  False
# 9205759     0.225     0.580   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.725     0.740   False   False  False   True
# 1          -0.905     0.715   False   False  False   True
# 2          -0.880     0.565   False   False  False   True
# 3          -0.720     0.310   False   False  False   True
# 4          -0.520     0.145   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.005    -0.170   False   False   True  False
# 9205756    -0.015    -0.185   False   False   True  False
# 9205757    -0.040    -0.185   False   False   True  False
# 9205758    -0.060    -0.190   False   False   True  False
# 9205759    -0.070    -0.210   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.265    -0.395   False   False  False   True
# 1          -0.260    -0.345   False   False  False   True
# 2          -0.265    -0.300   False   False  False   True
# 3          -0.265    -0.275   False   False  False   True
# 4          -0.260    -0.240   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.115    -0.130   False    True  False  False
# 9205756    -0.100    -0.110   False    True  False  False
# 9205757    -0.110    -0.125   False    True  False  False
# 9205758    -0.110    -0.130   False    True  False  False
# 9205759    -0.110    -0.135   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -2.255    -2.050   False   False  False   True
# 1          -2.220    -1.945   False   False  False   True
# 2          -2.050    -1.760   False   False  False   True
# 3          -1.840    -1.520   False   False  False   True
# 4          -1.530    -1.315   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.335     0.055   False    True  False  False
# 9205756    -0.340     0.065   False    True  False  False
# 9205757    -0.355     0.035   False    True  False  False
# 9205758    -0.355     0.020   False    True  False  False
# 9205759    -0.365     0.005   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -1.285     0.240   False   False  False   True
# 1           0.420     0.280   False   False  False   True
# 2           1.350     0.410   False   False  False   True
# 3          -0.470     0.470   False   False  False   True
# 4          -1.550     0.350   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.065     0.620   False   False   True  False
# 9205756     0.035     0.595   False   False   True  False
# 9205757     0.015     0.565   False   False   True  False
# 9205758    -0.050     0.470   False   False   True  False
# 9205759    -0.090     0.405   False   False   True  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.240    -0.240   False   False  False   True
# 1          -0.260    -0.235   False   False  False   True
# 2          -0.240    -0.230   False   False  False   True
# 3          -0.230    -0.200   False   False  False   True
# 4          -0.235    -0.205   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755     0.730    -0.470   False    True  False  False
# 9205756     0.710    -0.420   False    True  False  False
# 9205757     0.730    -0.470   False    True  False  False
# 9205758     0.740    -0.460   False    True  False  False
# 9205759     0.715    -0.455   False    True  False  False
#
# [9205760 rows x 6 columns],          Signal 1  Signal 2  R-Peak  Normal   AFIB  Other
# 0          -0.275    -0.370   False   False  False   True
# 1          -0.245    -0.450   False   False  False   True
# 2          -0.305    -0.430   False   False  False   True
# 3          -0.290    -0.385   False   False  False   True
# 4          -0.270    -0.335   False   False  False   True
# ...           ...       ...     ...     ...    ...    ...
# 9205755    -0.260    -0.580   False   False   True  False
# 9205756    -0.220    -0.525   False   False   True  False
# 9205757    -0.240    -0.520   False   False   True  False
# 9205758    -0.300    -0.520   False   False   True  False
# 9205759    -0.270    -0.565   False   False   True  False
#
# [9205760 rows x 6 columns]]

# %%
# Now we get the indexes of the R-Peaks from our dataframes
qrs = [] # Initialize the array that will hold our list of R-Peaks for each subject
qrs_colors= []
for subject in tqdm(subject_dataframes): # Load each subject
    qrs.append([idx for idx, x in enumerate(subject['R-Peak']) if x]) # Then we use list comprehension to get our r peaks for each subject
                                                                # Recall, the indices that the R-Peak column is true is where there is an r-peak
                                                                # So, we iterate through and identify which indices that is for each subject
for idx, subj in enumerate(tqdm(qrs)):    
    df_color = []
    for x in subj: 
        if subject_dataframes[idx].loc[x, 'Normal']: 
            df_color.append('Normal')
        elif subject_dataframes[idx].loc[x, 'AFIB']:
            df_color.append('AFIB')
        else: 
            df_color.append('Other')
    qrs_colors.append(df_color)
# Out:
# 100%|██████████| 23/23 [00:54<00:00,  2.36s/it]
# 100%|██████████| 23/23 [02:07<00:00,  5.53s/it]

# %%
print(len(qrs_colors[0]),len(qrs[0]))
# Out:
# 44005 44005

# %%
rr_ints = [] # Initialize the array that will hold all of our subjects' RR-Intervals
rhythms = []
for idx, subj in enumerate(tqdm(qrs)): # Iterate through our subjects data
    rrlabels = qrs_colors[idx]
    s_labels = []
    rr1 = [] # Initialize a temporary array that will store a single subject's RR-Intervals
    for idxs, r in enumerate(subj): # Iterate through the subject's R-Peaks
        if idxs == 0: # If it is the first peak we have no interval so go on to the next R-Peak
            next
        else:
            rr1.append(r - subj[idxs-1]) # Find the interval by taking the difference of the location of one R-Peak with the Location of the R-Peak before it
            s_labels.append(rrlabels[idxs])
    rr_ints.append(rr1) # Add it to our master array
    rhythms.append(s_labels)
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 33.08it/s]

# %% [raw]
# rr_ints = [] # Initialize the array that will hold all of our subjects' RR-Intervals
#
# for idx, subj in enumerate(record_list): # Iterate through our subject ids
#     rr_ints.append(np.genfromtxt('mit-bih-rr-intervals/'+str(subj)+'.csv',delimiter=',')) # Add to master array
#        #NOTE = change 'mit-bih-rr-intervals/' to the appropriate location

# %%
outlier_list=[]
rrs=[]
for idx, subj in tqdm(enumerate(rr_ints)):
    outlier = [[],[]] # I want to store the index and the outlier
    for idx2, rr in enumerate(subj):
        if rr > 500:
            outlier[0].append(rr) # add the rr int to our list
            outlier[1].append(idx2) # Add its index to our list
    subj = np.delete(subj, outlier[1]) # Remove all found outliers from our subject 
    rhythms[idx] = np.delete(rhythms[idx], outlier[1])
    rrs.append(subj) # Add it to our new rr interval list
    outlier_list.append(outlier)
# Out:
# 23it [00:02, 11.42it/s]

# %%
 # Setup subset dictionary
subset_list = {}
subset_rhythm_labels = {}
for x in record_list:
    subset_list[x] = []
    subset_rhythm_labels[x] = []

# %%
subset_len_sec = 25 # Set the time we are going to subset by
subset_len_samp = subset_len_sec*250 # Get that timme in samplse

for idx, subj in tqdm(enumerate(rrs)):
    samp = 0
    while samp < len(subj):
        subs_len = 0
        subs = []
        rhythm_list = []
        while subs_len < subset_len_samp and samp<len(subj):
            rr = subj[samp]
            subs.append(rr)
            rhythm_list.append(rhythms[idx][samp])
            subs_len+=rr
            samp+=1
        majority_rhythm = np.unique(rhythm_list)[np.argmax(np.unique(rhythm_list, return_counts=True)[1])]
        subset_list[record_list[idx]].append(subs)
        subset_rhythm_labels[record_list[idx]].append(majority_rhythm)
# Out:
# 23it [00:10,  2.15it/s]

# %%
subset_record_list = []
reload_flag=True
for idx, x in enumerate(tqdm(record_list)): 
    subset_record_list = []
    for num, subset in enumerate(subset_list[x]):
        if not os.path.exists('mit_bih_subset/'+x+ '-'+str(num)+'.csv') or reload_flag:
            np.savetxt('mit_bih_subset/'+x+ '-'+str(num)+'.csv', subset, delimiter=",",  fmt='%s') 
            
            subset_record_list.append(x+ '-'+str(num)+'.csv')
    if not os.path.exists('mit_bih_subset/'+x +'.csv') or reload_flag:
        pd.DataFrame({'subsetID': subset_record_list, 'rhythmLabel': subset_rhythm_labels[x]}).to_csv('mit_bih_subset/'+x+'_subset_dataframe.csv')
            # We'll load the complete list of subjects as well so that we can easily recreate the file names
# Out:
# 100%|██████████| 23/23 [00:48<00:00,  2.10s/it]
